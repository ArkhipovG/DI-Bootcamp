# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

city_names = [
    "Springfield", "Riverside", "Franklin", "Greenville", "Fairview", "Madison", "Georgetown", "Salem", "Arlington", "Milton"]
months = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October','November','December']

# %%
average_month_temperature = np.random.randint(-5,35,size=(10,12))
average_month_temperature
# Out:
# array([[19, 31,  8,  9, 30,  7, 10, -5,  6,  5, 16,  9],
#        [13,  4, 10, 29,  1,  2,  1, 11, -3, 28, 20, 32],
#        [17, 14, 21, 34, 23,  8, 34, 25, 25,  5, 16, 23],
#        [31, 12, 34, 19,  3, 16, 22,  6,  1,  9, 15, 27],
#        [16, 23, 17, -2,  8,  6, 20, 25, -2, -3, 20, 32],
#        [19, 21, 16, 25, 25, 26, 26, 27, 29, 25,  7, 27],
#        [23, 31, 12, 19, 15, -5, 19, -1,  4, -1, 13, 14],
#        [-1, 10,  3, 19, 31, 16,  5, 17, -2, 16, 15,  7],
#        [33, 20, 10,  2, 29,  0, 33,  4, 24, 17, -3, 22],
#        [16, 13, 18,  9, 23,  4, 30, 34, 19, 14, 32,  4]])

# %%
df_avg_temp = pd.DataFrame(data=average_month_temperature, index=city_names, columns=months)

# %%
df_avg_temp
# Out:
#              January  February  March  April  May  June  July  August  \
# Springfield       19        31      8      9   30     7    10      -5
# Riverside         13         4     10     29    1     2     1      11
# Franklin          17        14     21     34   23     8    34      25
# Greenville        31        12     34     19    3    16    22       6
# Fairview          16        23     17     -2    8     6    20      25
# Madison           19        21     16     25   25    26    26      27
# Georgetown        23        31     12     19   15    -5    19      -1
# Salem             -1        10      3     19   31    16     5      17
# Arlington         33        20     10      2   29     0    33       4
# Milton            16        13     18      9   23     4    30      34
#
#              September  October  November  December
# Springfield          6        5        16         9
# Riverside           -3       28        20        32
# Franklin            25        5        16        23
# Greenville           1        9        15        27
# Fairview            -2       -3        20        32
# Madison             29       25         7        27
# Georgetown           4       -1        13        14
# Salem               -2       16        15         7
# Arlington           24       17        -3        22
# Milton              19       14        32         4

# %%
df_avg_temp.mean()
# Out:
# January      18.6
# February     17.9
# March        14.9
# April        16.3
# May          18.8
# June          8.0
# July         20.0
# August       14.3
# September    10.1
# October      11.5
# November     15.1
# December     19.7
# dtype: float64

# %%
annual_avg_temp = df_avg_temp.mean(axis=0)
annual_avg_temp
# Out:
# January      18.6
# February     17.9
# March        14.9
# April        16.3
# May          18.8
# June          8.0
# July         20.0
# August       14.3
# September    10.1
# October      11.5
# November     15.1
# December     19.7
# dtype: float64

# %%
annual_avg_temp_by_city = df_avg_temp.mean(axis=1)
annual_avg_temp_by_city
# Out:
# Springfield    12.083333
# Riverside      12.333333
# Franklin       20.416667
# Greenville     16.250000
# Fairview       13.333333
# Madison        22.750000
# Georgetown     11.916667
# Salem          11.333333
# Arlington      15.916667
# Milton         18.000000
# dtype: float64

# %%
city_highest_temp = annual_avg_temp_by_city.idxmax()
city_lowest_temp = annual_avg_temp_by_city.idxmin()
print(f'The city with the highest average temperature: {city_highest_temp}')
print(f'The city with the lowest average temperature: {city_lowest_temp}')
# Out:
# The city with the highest average temperature: Madison
# The city with the lowest average temperature: Salem

# %% [markdown]
# Data Visualization:

# %%
df_avg_temp
# Out:
#              January  February  March  April  May  June  July  August  \
# Springfield       19        31      8      9   30     7    10      -5
# Riverside         13         4     10     29    1     2     1      11
# Franklin          17        14     21     34   23     8    34      25
# Greenville        31        12     34     19    3    16    22       6
# Fairview          16        23     17     -2    8     6    20      25
# Madison           19        21     16     25   25    26    26      27
# Georgetown        23        31     12     19   15    -5    19      -1
# Salem             -1        10      3     19   31    16     5      17
# Arlington         33        20     10      2   29     0    33       4
# Milton            16        13     18      9   23     4    30      34
#
#              September  October  November  December
# Springfield          6        5        16         9
# Riverside           -3       28        20        32
# Franklin            25        5        16        23
# Greenville           1        9        15        27
# Fairview            -2       -3        20        32
# Madison             29       25         7        27
# Georgetown           4       -1        13        14
# Salem               -2       16        15         7
# Arlington           24       17        -3        22
# Milton              19       14        32         4

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Reshape the DataFrame for plotting
df_avg_temp = df_avg_temp.stack().reset_index()
df_avg_temp.columns = ['City', 'Month', 'Temperature']

# Plot the average temperature by month for each city
plt.figure(figsize=(12, 8))
sns.lineplot(data=df_avg_temp, x='Month', y='Temperature', hue='City', markers=True, dashes=False)
plt.title('Average Temperature by Month for Each City')
plt.xlabel('Month')
plt.ylabel('Average Temperature (°C)')
plt.legend(title='City', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=df_avg_temp, x='Month', y='Temperature', hue='City')
plt.title('Average Temperature by Month for Each City')
plt.xlabel('Month')
plt.ylabel('Average Temperature (°C)')
plt.legend(title='City', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style
sns.set_style("whitegrid")

# Define the color palette
palette = sns.color_palette("viridis", len(annual_avg_temp_by_city))

plt.figure(figsize=(10, 6))
plt.bar(annual_avg_temp_by_city.index, annual_avg_temp_by_city, color=palette)
plt.title('Annual Average Temperature by City')
plt.xlabel('City')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df_avg_temp.hist()
# Out:
# array([[<Axes: title={'center': 'Temperature'}>]], dtype=object)

# %%
plt.figure(figsize=(10, 6))
sns.violinplot(data=df_avg_temp, inner="points", palette="muted")
plt.title('Distribution of Average Monthly Temperatures Across Cities')
plt.xlabel('Month')
plt.ylabel('Temperature (°C)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# The city with the highest average temperature: Mayohaven
# The city with the lowest average temperature: Laneberg
