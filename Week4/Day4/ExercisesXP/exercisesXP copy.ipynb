# %%
import pandas as pd
train_data = pd.read_csv('/Users/grigorijarhipov/Documents/Developers.Institute/GITHUB/DI-Bootcamp/Week4/Day4/ExercisesXP/titanic/train.csv')
train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
print(f" train_data duplicates: {train_data.duplicated().sum()}")
# Out:
#  train_data duplicates: 0

# %%
print(f" train_data missing values count: \n{train_data.isnull().sum()}\n")
# Out:
#  train_data missing values count:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Drop column: 'Cabin' beacause there is 77% missing values
cleaned_train_data = train_data.drop(columns=['Cabin'])
cleaned_train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Replace gaps forward from the previous valid value in: 'Age'
cleaned_train_data = cleaned_train_data.fillna({'Age': cleaned_train_data['Age'].ffill()})
cleaned_train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Replace missing values with the most common value of each column in: 'Embarked'
cleaned_train_data = cleaned_train_data.fillna({'Embarked': cleaned_train_data['Embarked'].mode()[0]})
cleaned_train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
cleaned_train_data['Family Size'] = cleaned_train_data['SibSp'] + cleaned_train_data['Parch']
cleaned_train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
cleaned_train_data["Title"] = cleaned_train_data['Name'].str.split(',').str[0]
cleaned_train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# Create LabelEncoder object

onehot_encoder = OneHotEncoder()
encoded_cleaned_train_data = cleaned_train_data
# Encode the categorical variable
encoded = onehot_encoder.fit_transform(encoded_cleaned_train_data['Sex'].to_numpy().reshape(-1, 1)).toarray()
encoded_cleaned_train_data['Sex']= encoded

# %%
encoded_cleaned_train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  0.0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  1.0  38.0      1
# 2                               Heikkinen, Miss. Laina  1.0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  1.0  35.0      1
# 4                             Allen, Mr. William Henry  0.0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Create LabelEncoder object
label_encoder = LabelEncoder()

# Encode the categorical variable
encoded_labels = label_encoder.fit_transform(encoded_cleaned_train_data['Embarked'])
encoded_cleaned_train_data['Embarked']=encoded_labels

# %%
encoded_cleaned_train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris  0.0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  1.0  38.0      1
# 2                               Heikkinen, Miss. Laina  1.0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  1.0  35.0      1
# 4                             Allen, Mr. William Henry  0.0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
cleaned_train_data = encoded_cleaned_train_data

# %%
Q1F = cleaned_train_data['Fare'].quantile(0.25)
Q3F = cleaned_train_data['Fare'].quantile(0.75)
IQRF = Q3F - Q1F
lower_boundF = Q1F - 1.5 * IQRF
upper_boundF = Q3F + 1.5 * IQRF
print(lower_boundF,upper_boundF)
outliers_data_fare = cleaned_train_data[(cleaned_train_data['Fare'] < lower_boundF) | (cleaned_train_data['Fare'] > upper_boundF)]
cleaned_train_data = cleaned_train_data[(cleaned_train_data['Fare'] >= lower_boundF) & (cleaned_train_data['Fare'] <= upper_boundF)]
# Out:
# -26.724 65.6344

# %%
Q1A = cleaned_train_data['Age'].quantile(0.25)
Q3A = cleaned_train_data['Age'].quantile(0.75)
IQRA = Q3A - Q1A
lower_boundA = Q1A - 1.5 * IQRA
upper_boundA = Q3A + 1.5 * IQRA
print(lower_boundA,upper_boundA)
outliers_data_ages = cleaned_train_data[(cleaned_train_data['Age'] < lower_boundA) | (cleaned_train_data['Age'] > upper_boundA)]
cleaned_train_data = cleaned_train_data[(cleaned_train_data['Age'] >= lower_boundA) & (cleaned_train_data['Age'] <= upper_boundA)]
# Out:
# -5.5 62.5

# %%
cleaned_train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris  0.0  22.0      1      0
# 2                          Heikkinen, Miss. Laina  1.0  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  1.0  35.0      1      0
# 4                        Allen, Mr. William Henry  0.0  35.0      0      0
# 5                                Moran, Mr. James  0.0  35.0      0      0
# ..                                            ...  ...   ...    ...    ...
# ...

# %%
outliers_data_ages
# Out:
#      PassengerId  Survived  Pclass                                  Name  Sex  \
# 33            34         0       2                 Wheadon, Mr. Edward H  0.0
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius  0.0
# 55            56         1       1                     Woolner, Mr. Hugh  0.0
# 96            97         0       1             Goldschmidt, Mr. George B  0.0
# 116          117         0       3                  Connors, Mr. Patrick  0.0
# 280          281         0       3                      Duane, Mr. Frank  0.0
# 456          457         0       1             Millet, Mr. Francis Davis  0.0
# 457          458         1       1     Kenyon, Mrs. Frederick R (Marion)  1.0
# 483          484         1       3                Turkula, Mrs. (Hedwig)  1.0
# 493          494         0       1               Artagaveytia, Mr. Ramon  0.0
# 545          546         0       1          Nicholson, Mr. Arthur Ernest  0.0
# ...

# %%
outliers_data_fare['Fare'].min()
# Out:
# 66.6

# %%
outliers_data_fare['Fare'].max()
# Out:
# 512.3292

# %%
cleaned_train_data['Fare'].min()
# Out:
# 0.0

# %%
Q1F
# Out:
# 7.9104

# %%
Q3F
# Out:
# 31.0

# %%
outliers_data_fare
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 52            53         1       1
# ..           ...       ...     ...
# 846          847         0       3
# 849          850         1       1
# 856          857         1       1
# 863          864         0       3
# 879          880         1       1
#
#                                                   Name  Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  1.0  38.0      1
# 27                      Fortune, Mr. Charles Alexander  0.0  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  1.0  40.0      1
# 34                             Meyer, Mr. Edgar Joseph  0.0  28.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  1.0  49.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
cleaned_train_data['Age_normalized'] = scaler.fit_transform(cleaned_train_data[['Age']])

# %%
cleaned_train_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris  0.0  22.0      1      0
# 2                          Heikkinen, Miss. Laina  1.0  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  1.0  35.0      1      0
# 4                        Allen, Mr. William Henry  0.0  35.0      0      0
# 5                                Moran, Mr. James  0.0  35.0      0      0
# ..                                            ...  ...   ...    ...    ...
# ...

# %%
cleaned_train_data['Embarked'] = cleaned_train_data['Embarked'].astype('category')
encoded_cleaned_train_data2= pd.get_dummies(cleaned_train_data, columns=['Embarked'], prefix='Port', prefix_sep='_')

# %%
encoded_cleaned_train_data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris  0.0  22.0      1      0
# 2                          Heikkinen, Miss. Laina  1.0  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  1.0  35.0      1      0
# 4                        Allen, Mr. William Henry  0.0  35.0      0      0
# 5                                Moran, Mr. James  0.0  35.0      0      0
# ..                                            ...  ...   ...    ...    ...
# ...

# %%
age_bins = [0, 18, 30, 40, 50, 60, 80]  
age_labels = ['0-17', '18-29', '30-39', '40-49', '50-59', '60+']

cleaned_train_data['AgeGroup'] = pd.cut(cleaned_train_data['Age'], bins=age_bins, labels=age_labels, right=False)

age_groups_encoded = pd.get_dummies(cleaned_train_data['AgeGroup'], prefix='AgeGroup')

encoded_cleaned_train_data2 = pd.concat([cleaned_train_data, age_groups_encoded], axis=1)

# %%
encoded_cleaned_train_data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris  0.0  22.0      1      0
# 2                          Heikkinen, Miss. Laina  1.0  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  1.0  35.0      1      0
# 4                        Allen, Mr. William Henry  0.0  35.0      0      0
# 5                                Moran, Mr. James  0.0  35.0      0      0
# ..                                            ...  ...   ...    ...    ...
# ...

# %%
cleaned_train_data['Age_group'] = pd.cut(cleaned_train_data['Age'], bins=[0, 15, 30, 45, 60, 75])

grouped_df = cleaned_train_data.groupby('Age_group')['Age'].mean().reset_index()
grouped_df
# Out:
# /var/folders/0y/9ghc01ls5k5bh2rpf5gh4whc0000gn/T/ipykernel_55613/2438804064.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_df = cleaned_train_data.groupby('Age_group')['Age'].mean().reset_index()
#   Age_group        Age
# 0   (0, 15]   5.931939
# 1  (15, 30]  23.206461
# 2  (30, 45]  36.865909
# 3  (45, 60]  51.635802
# 4  (60, 75]  61.500000
